# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
# Welcome to your new notebook
# Type here in the cell editor to add code!
from pyspark.sql.types import *
    
# Create the schema for the table
orderSchema = StructType([
    StructField("MatchUp", StringType()),
    StructField("IN", StringType()),
    StructField("OUT", StringType())
    ])
    
# Import all files from bronze folder of lakehouse
df = spark.read.format("csv").option("header", "false").option("delimiter", ";").schema(orderSchema).load("abfss://MTG_DEV@onelake.dfs.fabric.microsoft.com/Decks.Lakehouse/Files/Strom/*.csv")
    
# Display the first 10 rows of the dataframe to preview your data
display(df.head(10))
# Out:
# StatementMeta(, 12db826b-32b3-4a0c-ad87-10a64ecaa61e, 3, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, a2caf8f3-e8fe-4cb8-8d23-8f4ff3e082f7)
